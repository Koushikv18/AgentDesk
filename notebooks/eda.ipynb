# %%
import pandas as pd

# %%
	import pandas as pd
	from pathlib import Path
	# Notebook lives in the `notebooks/` folder; CSV is in `Data/` alongside it
	csv_path = Path('..') / 'Data' / 'customer_support_tickets.csv'
	print('Loading CSV from', csv_path.resolve())
	df = pd.read_csv(csv_path)
	df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv(Data/customer_support_tickets.csv)
#
# NameError: name 'Data' is not defined
